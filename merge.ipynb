# %%
import os
import pandas as pd

# %%
list_hhgso = [i for i in os.listdir() if i.endswith('hgso.csv')]

# %%
list_hhgso[0][:-10]
# Out:
# 'Rosenbrock'

# %%
df = pd.DataFrame()

for data in list_hhgso:
    temp = pd.read_csv(data)
    df[data[:-16]]= temp['fitness']

# %%
df.to_csv("Triple_Check_Exploration.csv", index=False)

# %%
df['Rosenbrock'].plot(kind='line')
# Out:
# <Axes: >
